# %%
import seaborn as sns

# %%
import statistics as stats

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips["total_bill"],kde= False,bins=30)

sns.set()

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")

# %%
sns.pairplot(tips, hue ="sex",palette="coolwarm")

# %%
sns.rugplot(tips["total_bill"])

# %%
sns.distplot(tips["total_bill"],kde = False)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)

# %%
sns.countplot(x="sex",data=tips)

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue="smoker")

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue="sex",split=True)
# Out:
# C:\Users\mkdty\anaconda3\lib\site-packages\seaborn\categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,color="black")
sns.violinplot(x="day",y="total_bill",data=tips)

# %%
import numpy as np

# %% [markdown]
# # class

# %%
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %%
diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
penguins = penguins.dropna()

# %%
sns.distplot(penguins["body_mass_g"],kde = False)

# %%
plt.hist(penguins["body_mass_g"],edgecolor="k")
# Out:
# (array([14., 42., 69., 52., 41., 39., 27., 27., 16.,  6.]),
#  array([2700., 3060., 3420., 3780., 4140., 4500., 4860., 5220., 5580.,
#         5940., 6300.]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(penguins["body_mass_g"],hist_kws = dict(edgecolor="k",lw=1),bins = 15,kde = False)

# %%
sns.distplot(penguins["body_mass_g"],hist=False,rug = True)

# %%
sns.distplot(penguins["body_mass_g"],hist=False,rug = True)

# %%
import numpy as np

# %%
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)
# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)
# Generate a random univariate dataset
d = rs.normal(size=100)
# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])
# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])
# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])
# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])
plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
mean = penguins["body_mass_g"].mean()

# %%
fig , ax = plt.subplots(figsize=(8,6))
sns.distplot(penguins["body_mass_g"],kde=False, ax = ax)

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
sns.distplot(geyser["waiting"],kde=False)

# %%
geyser["waiting"].mean()
# Out:
# 70.8970588235294

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips["total_bill"],kde=False)

# %% [markdown]
# ## jointplot

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="scatter")
sns.set()

# %%
sns.distplot(tips.tip,kde=False)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind = "scatter")
sns.set()

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.scatterplot(x="total_bill",hue="sex",y="tip",data = tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind = "hex")
sns.set()

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind = "reg")
sns.set() # lm plot regresyon

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind = "kde")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.pairplot(mpg);

# %%
mpg = mpg.drop(["displacement"],axis=1)

# %%
mpg.head()
# Out:
#     mpg  cylinders  horsepower  weight  acceleration  model_year origin  \
# 0  18.0          8       130.0    3504          12.0          70    usa
# 1  15.0          8       165.0    3693          11.5          70    usa
# 2  18.0          8       150.0    3436          11.0          70    usa
# 3  16.0          8       150.0    3433          12.0          70    usa
# 4  17.0          8       140.0    3449          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
mpg.describe()
# Out:
#               mpg   cylinders  horsepower       weight  acceleration  \
# count  398.000000  398.000000  392.000000   398.000000    398.000000
# mean    23.514573    5.454774  104.469388  2970.424623     15.568090
# std      7.815984    1.701004   38.491160   846.841774      2.757689
# min      9.000000    3.000000   46.000000  1613.000000      8.000000
# 25%     17.500000    4.000000   75.000000  2223.750000     13.825000
# 50%     23.000000    4.000000   93.500000  2803.500000     15.500000
# 75%     29.000000    8.000000  126.000000  3608.000000     17.175000
# max     46.600000    8.000000  230.000000  5140.000000     24.800000
#
#        model_year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %%
mpg[["horsepower","cylinders"]][mpg.cylinders==3]
# Out:
#      horsepower  cylinders
# 71         97.0          3
# 111        90.0          3
# 243       110.0          3
# 334       100.0          3

# %%
sns.boxplot(x="cylinders",y="horsepower",data=mpg,hue="origin")

# %%
mpg.groupby("model_year").mpg.mean().plot()

# %%
mpg.groupby("model_year").mpg.mean().plot(kind="bar")

# %%
mpg.groupby("model_year").mpg.mean().plot.bar()

# %%
mpg.groupby("model_year")["horsepower"].mean().plot();

# %%
sns.pairplot(mpg,hue="cylinders");

# %% [markdown]
# # categorical

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
df = pd.DataFrame(list(zip(labels, men_means, women_means)), columns =["labels", "men_means", "women_means"])
df.head()
# Out:
#   labels  men_means  women_means
# 0     G1         20           25
# 1     G2         34           32
# 2     G3         30           34
# 3     G4         35           20
# 4     G5         27           25

# %%
list(zip(labels, men_means, women_means))
# Out:
# [('G1', 20, 25),
#  ('G2', 34, 32),
#  ('G3', 30, 34),
#  ('G4', 35, 20),
#  ('G5', 27, 25)]

# %%
plt.bar(df["labels"],df["men_means"])
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots(figsize = (12,6))
sns.barplot(df["labels"],df["men_means"])
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5));

# %%
sns.barplot("labels","men_means",data = df)

# %%
#order
sns.barplot("labels","men_means",data = df,order=["G1","G5","G3","G2","G4"]) # yazdığın sıraya göre çizdirir

# %%
sns.barplot("labels","men_means",data = df,order=df.sort_values("men_means",ascending=False).labels)

# %%
y=[59219,55466,47544,36443,35917,31991,27097,23030,20524,18523,18017,7920,7331,7201,5833]

x= ['JavaScript',
 'HTML/CSS',
 'SQL',
 'Python',
 'Java',
 'Bash/Shel/PS',
 'C#',
 'PHP',
 'C++',
 'TypeScript',
 'C',
 'Other(s):',
 'Ruby',
 'Go',
 'Assembly']

fig, ax = plt.subplots(figsize=(15, 7))
rects1=ax.bar(x,y)
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(rects1)        
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);

# %%
fig, ax = plt.subplots(figsize=(15, 7))
#rects1=sns.barplot(x, y) # if there any subplot one or more use "ax" parameter --> ax=ax[1]
rects1=ax.bar(x,y)
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(rects1)

# %%
# barplot (actual)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="sex",y="total_bill",data=tips) # otomatik groupby yapıyor seaborn

# %%
tips.groupby("sex")["total_bill"].mean().plot.bar(edgecolor="black")

# %%
aa =tips.groupby("sex")["total_bill"].mean() 
plt.bar(aa.index,aa.values)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.barplot("sex","total_bill",ci=None,data=tips)

# %%
sns.barplot("sex","total_bill",ci=90,data=tips)

# %%
sns.barplot("sex","total_bill",ci=90,hue="smoker",data=tips)

# %%
sns.barplot("sex","tip",hue="day",data=tips)

# %%
sns.barplot("day","tip",hue="sex",data=tips)

# %%
sns.barplot("day","tip",data=tips)

# %%
mpg.head()
# Out:
#     mpg  cylinders  horsepower  weight  acceleration  model_year origin  \
# 0  18.0          8       130.0    3504          12.0          70    usa
# 1  15.0          8       165.0    3693          11.5          70    usa
# 2  18.0          8       150.0    3436          11.0          70    usa
# 3  16.0          8       150.0    3433          12.0          70    usa
# 4  17.0          8       140.0    3449          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
fig,ax= plt.subplots(figsize=(12,7))
sns.barplot("cylinders","horsepower",data=mpg)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot("age","sex",hue="pclass",data=titanic)

# %%
sns.barplot("sex","age",hue="class",data=titanic)

# %% [markdown]
# # countplot

# %%
sns.countplot(x="sex",data=tips)

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().plot(kind="bar")

# %%
mpg.head()
# Out:
#     mpg  cylinders  horsepower  weight  acceleration  model_year origin  \
# 0  18.0          8       130.0    3504          12.0          70    usa
# 1  15.0          8       165.0    3693          11.5          70    usa
# 2  18.0          8       150.0    3436          11.0          70    usa
# 3  16.0          8       150.0    3433          12.0          70    usa
# 4  17.0          8       140.0    3449          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
sns.countplot("cylinders", data=mpg,order=[4,8,6,3,5])

# %%
sns.countplot("model_year",data= mpg)

# %%
sns.countplot(x="origin",data = mpg)

# %%
sns.boxplot(tips["total_bill"],orient="v",width=0.5)

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue="sex")

# %%
mpg.head()
# Out:
#     mpg  cylinders  horsepower  weight  acceleration  model_year origin  \
# 0  18.0          8       130.0    3504          12.0          70    usa
# 1  15.0          8       165.0    3693          11.5          70    usa
# 2  18.0          8       150.0    3436          11.0          70    usa
# 3  16.0          8       150.0    3433          12.0          70    usa
# 4  17.0          8       140.0    3449          10.5          70    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
sns.boxplot("origin","horsepower",hue="origin",data=mpg)

# %%
# violin plot

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
sns.despine()

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips)

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips,split=True) # erkekler bi tarafta kadınlar bir tarafta

# %%
#stripplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(x="day",y="total_bill",hue="sex",data=tips) 
# x categorical y numeric scatter plot ın categoricli hali
plt.legend(loc=2)

# %%
sns.stripplot(x="day",y="total_bill",hue="sex",data=tips,dodge=True) # iç içe değil ayrı plotluyor

# %%
sns.stripplot(x="day",y="total_bill",hue="sex",data=tips,dodge=True,jitter=False)
sns.despine()

# %%
#swarmplot strip + violin

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,hue="sex",dodge=True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.swarmplot(x="class",y="age",data=titanic,hue="survived",dodge=True)
# Out:
# C:\Users\mkdty\anaconda3\lib\site-packages\seaborn\categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\mkdty\anaconda3\lib\site-packages\seaborn\categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.swarmplot(x="origin",y="horsepower",data=mpg,hue="cylinders")

# %%
# catplot

# %%
sns.catplot(x="sex",y="total_bill",data=tips,kind="bar")

# %%
sns.catplot(x="sex",y="total_bill",hue="smoker",data=tips,kind="strip",dodge=True)

# %%
sns.pointplot("time","total_bill",data=tips)

# %%
sns.barplot("time","total_bill",data=tips)

# %%
#plt.xticks(rotation = 45)
#plt.title("Most common 15 Name or Surname of killed people")
#plt.ylabel("Frequency")
#plt.xlabel("Name or Surname of killed people")
#for p in ax.patches:
    #ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5));

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')
mpg=sns.load_dataset('mpg')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(),annot=True)

# %%
sns.heatmap(tips.corr(),annot=True,cmap="coolwarm",edgecolor="black")

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.pivot_table(values="passengers",index="month",columns="year")
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
a = flights.pivot_table(values="passengers",index="month",columns="year")

# %%
sns.heatmap(a)

# %%
sns.heatmap(a,linecolor="white",linewidths=0.5)

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.heatmap(mpg.corr())

# %%
import matplotlib.pyplot as plt
fig = plt.subplots(figsize=(12,7))
sns.heatmap(mpg.corr(),linecolor="white",linewidths=0.5,annot=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips,diag_kind="kde")
#ortadakini değiştirebiliyoruz

# %%
sns.pairplot(tips,hue="sex")

# %%
#pairgrid

# %%
sns.PairGrid(tips)

# %%
g = sns.PairGrid(tips)
g.map(plt.scatter)
#içine istediğini çizdiriyorsun

# %%
g = sns.PairGrid(tips)

g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# # Facet Grid

# %%
gg = sns.FacetGrid(tips,col="time",hue="smoker")

# %%
g = sns.FacetGrid(tips,col="time")
g.map(plt.hist,"total_bill")

# %%
gg = sns.FacetGrid(tips,col="time",row="smoker")
gg.map(plt.hist,"total_bill")

# %%
gg = sns.FacetGrid(tips,col="day",row="smoker")
gg.map(plt.hist,"total_bill")

# %% [markdown]
# # LMPLOT

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,ci=95)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,hue="sex")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,col="sex")# ayrı ayrı çizdirdi gender a göre

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,row="sex")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,row="sex",col="time")

# %%
plt.figure(figsize=(15,10))
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,row="sex",col="time")

# %%
# aspect and height (former "size")

# %%
sns.set_context("notebook",font_scale=1)
sns.lmplot(x="total_bill",y="tip",data=tips,ci=99,row="time",col="sex",aspect=2,height=6)

# %% [markdown]
# # style and color

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot("time",data=tips)

# %%
sns.countplot("sex",data=tips)

# %%
sns.set_style("white")
sns.countplot(x="sex",data=tips)

# %%
sns.set_style("dark")
sns.countplot(x="sex",data=tips)

# %%
sns.set_style("darkgrid")
sns.countplot(x="sex",data=tips)

# %%
plt.style.use("ggplot")
sns.countplot(x="sex",data=tips)

# %%
# spine removal

# %%
sns.set_style("white")
sns.countplot(x="sex",data=tips)
sns.despine(left=True,bottom=True,top=False)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,6))
sns.countplot(x="sex",data=tips)

# %%
sns.set_context("poster")
sns.countplot(x="sex",data=tips)

# %%
sns.set_context("notebook")
sns.countplot(x="sex",data=tips)

# %%
sns.set_context("paper")
sns.countplot(x="sex",data=tips)

# %%
sns.set_context("notebook",font_scale=1.5)
sns.countplot(x="sex",data=tips)

# %%
sns.set_context("talk", rc={"lines.linewidth": 5})
sns.countplot(x="sex",data=tips)

# %%
# color

# %%
x= ['JavaScript',
 'HTML/CSS',
 'SQL',
 'Python',
 'Java',
 'Bash/Shel/PS',
 'C#',
 'PHP',
 'C++',
 'TypeScript',
 'C',
 'Other(s):',
 'Ruby',
 'Go',
 'Assembly']
y=[59219,
 55466,
 47544,
 36443,
 35917,
 31991,
 27097,
 23030,
 20524,
 18523,
 18017,
 7920,
 7331,
 7201,
 5833]

fig, ax = plt.subplots(figsize=(15, 7))
sns.set_context('notebook')
sns.barplot(x,y, palette="seismic")
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);

# %%
x= ['JavaScript',
 'HTML/CSS',
 'SQL',
 'Python',
 'Java',
 'Bash/Shel/PS',
 'C#',
 'PHP',
 'C++',
 'TypeScript',
 'C',
 'Other(s):',
 'Ruby',
 'Go',
 'Assembly']
y=[59219,
 55466,
 47544,
 36443,
 35917,
 31991,
 27097,
 23030,
 20524,
 18523,
 18017,
 7920,
 7331,
 7201,
 5833]

fig, ax = plt.subplots(figsize=(15, 7))
sns.set_context('notebook')
sns.barplot(x,y, palette="magma")
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5));

# %%
import pandas as pd

# %%
df=pd.read_csv("cleaned_autos.csv")

# %%
df
# Out:
#                 dateCrawled                                   name  seller  \
# 0       2016-03-24 11:52:17                             Golf_3_1.6  privat
# 1       2016-03-24 10:58:45                   A5_Sportback_2.7_Tdi  privat
# 2       2016-03-14 12:52:21         Jeep_Grand_Cherokee_"Overland"  privat
# 3       2016-03-17 16:54:04                     GOLF_4_1_4__3TÜRER  privat
# 4       2016-03-31 17:25:20         Skoda_Fabia_1.4_TDI_PD_Classic  privat
# ...                     ...                                    ...     ...
# 313682  2016-03-21 09:50:58                        Mitsubishi_Cold  privat
# 313683  2016-03-14 17:48:27             Suche_t4___vito_ab_6_sitze  privat
# 313684  2016-03-05 19:56:21  Smart_smart_leistungssteigerung_100ps  privat
# 313685  2016-03-19 18:57:12     Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 313686  2016-03-20 19:41:08                 VW_Golf_Kombi_1_9l_TDI  privat
#
# ...
